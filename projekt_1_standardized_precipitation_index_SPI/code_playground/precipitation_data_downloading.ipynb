# %% [markdown]
# # Precipitation Data Downloader
# The aim of the notebook is to download and extract precipitation data at a daily granularity

# %% [markdown]
# ## Import Statements

# %%
import requests
from bs4 import BeautifulSoup
import os
import zipfile

# %%
# DATA_URL = "https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_hydrologiczne/dobowe/"
DATA_URL = "https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/"

# %% [markdown]
# ## Functions

# %%
def get_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all("a") 
    links = [link.get("href") for link in links]
    return links


def download(url, save_dir="."):
    # Send a GET request to the URL
    response = requests.get(url)
    # Check if request was successful
    if response.status_code == 200:
        # Get the file name from the URL
        filename = os.path.basename(url)
        # Combine the directory and file name to get the full path
        filepath = os.path.join(save_dir, filename)
        # Write the content to a file
        with open(filepath, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"File '{filename}' downloaded successfully.")
        # Extract the contents of the ZIP file
        with zipfile.ZipFile(filepath, 'r') as zip_ref:
            zip_ref.extractall(save_dir)
        print("ZIP file contents extracted successfully.")
    else:
        print("Failed to download the file.")

def remove_zip_files(directory):
    # Get the list of all files in the directory
    files = os.listdir(directory)
    # Iterate through each file
    for file in files:
        # Check if the file is a .zip file
        if file.endswith('.zip'):
            # Construct the full path to the file
            file_path = os.path.join(directory, file)
            # Remove the file
            os.remove(file_path)
            print(f"File '{file}' removed successfully.")

# %% [markdown]
# ## Downloading

# %%
res = get_links(DATA_URL)
data_links = []
output_data_path = "data/precipitation"

if not os.path.exists(output_data_path):
    os.makedirs(output_data_path, exist_ok=True)

for link in res:
    if link[:4].isdigit():
        temp = DATA_URL+link
        zip_files_by_year = get_links(temp)
        zip_files_by_year = [temp+link for link in zip_files_by_year if ".zip" in link]
        year = str(temp.split("/")[-2])

        year_path = os.path.join(output_data_path, year)
        if not os.path.exists(year_path):
            os.mkdir(year_path)

        for zip_url in zip_files_by_year:
            print(zip_url)
            download(zip_url,year_path)  
        remove_zip_files(year_path)
# Out:
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1950_o.zip
# File '1950_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1951_o.zip
# File '1951_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1952_o.zip
# File '1952_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1953_o.zip
# File '1953_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1954_o.zip
# File '1954_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1950_1955/1955_o.zip
# File '1955_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '1950_o.zip' removed successfully.
# File '1951_o.zip' removed successfully.
# File '1952_o.zip' removed successfully.
# File '1953_o.zip' removed successfully.
# File '1954_o.zip' removed successfully.
# File '1955_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1956_1960/1956_o.zip
# File '1956_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1956_1960/1957_o.zip
# File '1957_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1956_1960/1958_o.zip
# File '1958_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1956_1960/1959_o.zip
# File '1959_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1956_1960/1960_o.zip
# File '1960_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '1956_o.zip' removed successfully.
# File '1957_o.zip' removed successfully.
# File '1958_o.zip' removed successfully.
# File '1959_o.zip' removed successfully.
# File '1960_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1961_1965/1961_o.zip
# File '1961_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1961_1965/1962_o.zip
# File '1962_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1961_1965/1963_o.zip
# File '1963_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1961_1965/1964_o.zip
# File '1964_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1961_1965/1965_o.zip
# File '1965_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '1961_o.zip' removed successfully.
# File '1962_o.zip' removed successfully.
# File '1963_o.zip' removed successfully.
# File '1964_o.zip' removed successfully.
# File '1965_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1966_1970/1966_o.zip
# File '1966_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1966_1970/1967_o.zip
# File '1967_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/1966_1970/1968_o.zip
# File '1968_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/
07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2009/2009_08_o.zip
# File '2009_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2009/2009_09_o.zip
# File '2009_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2009/2009_10_o.zip
# File '2009_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2009/2009_11_o.zip
# File '2009_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2009/2009_12_o.zip
# File '2009_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2009_01_o.zip' removed successfully.
# File '2009_02_o.zip' removed successfully.
# File '2009_03_o.zip' removed successfully.
# File '2009_04_o.zip' removed successfully.
# File '2009_05_o.zip' removed successfully.
# File '2009_06_o.zip' removed successfully.
# File '2009_07_o.zip' removed successfully.
# File '2009_08_o.zip' removed successfully.
# File '2009_09_o.zip' removed successfully.
# File '2009_10_o.zip' removed successfully.
# File '2009_11_o.zip' removed successfully.
# File '2009_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_01_o.zip
# File '2010_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_02_o.zip
# File '2010_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_03_o.zip
# File '2010_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_04_o.zip
# File '2010_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_05_o.zip
# File '2010_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_06_o.zip
# File '2010_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_07_o.zip
# File '2010_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_08_o.zip
# File '2010_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_09_o.zip
# File '2010_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_10_o.zip
# File '2010_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_11_o.zip
# File '2010_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2010/2010_12_o.zip
# File '2010_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2010_01_o.zip' removed successfully.
# File '2010_02_o.zip' removed successfully.
# File '2010_03_o.zip' removed successfully.
# File '2010_04_o.zip' removed successfully.
# File '2010_05_o.zip' removed successfully.
# File '2010_06_o.zip' removed successfully.
# File '2010_07_o.zip' removed successfully.
# File '2010_08_o.zip' removed successfully.
# File '2010_09_o.zip' removed successfully.
# File '2010_10_o.zip' removed successfully.
# File '2010_11_o.zip' removed successfully.
# File '2010_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_01_o.zip
# File '2011_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_02_o.zip
# File '2011_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_03_o.zip
# File '2011_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_04_o.zip
# File '2011_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_05_o.zip
# File '2011_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_06_o.zip
# File '2011_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_07_o.zip
# File '2011_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_08_o.zip
# File '2011_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_09_o.zip
# File '2011_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_10_o.zip
# File '2011_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_11_o.zip
# File '2011_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2011/2011_12_o.zip
# File '2011_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2011_01_o.zip' removed successfully.
# File '2011_02_o.zip' removed successfully.
# File '2011_03_o.zip' removed successfully.
# File '2011_04_o.zip' removed successfully.
# File '2011_05_o.zip' removed successfully.
# File '2011_06_o.zip' removed successfully.
# File '2011_07_o.zip' removed successfully.
# File '2011_08_o.zip' removed successfully.
# File '2011_09_o.zip' removed successfully.
# File '2011_10_o.zip' removed successfully.
# File '2011_11_o.zip' removed successfully.
# File '2011_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_01_o.zip
# File '2012_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_02_o.zip
# File '2012_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_03_o.zip
# File '2012_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_04_o.zip
# File '2012_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_05_o.zip
# File '2012_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_06_o.zip
# File '2012_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_07_o.zip
# File '2012_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_08_o.zip
# File '2012_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_09_o.zip
# File '2012_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_10_o.zip
# File '2012_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_11_o.zip
# File '2012_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2012/2012_12_o.zip
# File '2012_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2012_01_o.zip' removed successfully.
# File '2012_02_o.zip' removed successfully.
# File '2012_03_o.zip' removed successfully.
# File '2012_04_o.zip' removed successfully.
# File '2012_05_o.zip' removed successfully.
# File '2012_06_o.zip' removed successfully.
# File '2012_07_o.zip' removed successfully.
# File '2012_08_o.zip' removed successfully.
# File '2012_09_o.zip' removed successfully.
# File '2012_10_o.zip' removed successfully.
# File '2012_11_o.zip' removed successfully.
# File '2012_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2013/2013_01_o.zip
# File '2013_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# ...
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2018/2018_08_o.zip
# File '2018_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2018/2018_09_o.zip
# File '2018_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2018/2018_10_o.zip
# File '2018_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2018/2018_11_o.zip
# File '2018_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2018/2018_12_o.zip
# File '2018_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2018_01_o.zip' removed successfully.
# File '2018_02_o.zip' removed successfully.
# File '2018_03_o.zip' removed successfully.
# File '2018_04_o.zip' removed successfully.
# File '2018_05_o.zip' removed successfully.
# File '2018_06_o.zip' removed successfully.
# File '2018_07_o.zip' removed successfully.
# File '2018_08_o.zip' removed successfully.
# File '2018_09_o.zip' removed successfully.
# File '2018_10_o.zip' removed successfully.
# File '2018_11_o.zip' removed successfully.
# File '2018_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_01_o.zip
# File '2019_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_02_o.zip
# File '2019_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_03_o.zip
# File '2019_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_04_o.zip
# File '2019_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_05_o.zip
# File '2019_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_06_o.zip
# File '2019_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_07_o.zip
# File '2019_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_08_o.zip
# File '2019_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_09_o.zip
# File '2019_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_10_o.zip
# File '2019_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_11_o.zip
# File '2019_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2019/2019_12_o.zip
# File '2019_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2019_01_o.zip' removed successfully.
# File '2019_02_o.zip' removed successfully.
# File '2019_03_o.zip' removed successfully.
# File '2019_04_o.zip' removed successfully.
# File '2019_05_o.zip' removed successfully.
# File '2019_06_o.zip' removed successfully.
# File '2019_07_o.zip' removed successfully.
# File '2019_08_o.zip' removed successfully.
# File '2019_09_o.zip' removed successfully.
# File '2019_10_o.zip' removed successfully.
# File '2019_11_o.zip' removed successfully.
# File '2019_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_01_o.zip
# File '2020_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_02_o.zip
# File '2020_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_03_o.zip
# File '2020_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_04_o.zip
# File '2020_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_05_o.zip
# File '2020_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_06_o.zip
# File '2020_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_07_o.zip
# File '2020_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_08_o.zip
# File '2020_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_09_o.zip
# File '2020_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_10_o.zip
# File '2020_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_11_o.zip
# File '2020_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2020/2020_12_o.zip
# File '2020_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2020_01_o.zip' removed successfully.
# File '2020_02_o.zip' removed successfully.
# File '2020_03_o.zip' removed successfully.
# File '2020_04_o.zip' removed successfully.
# File '2020_05_o.zip' removed successfully.
# File '2020_06_o.zip' removed successfully.
# File '2020_07_o.zip' removed successfully.
# File '2020_08_o.zip' removed successfully.
# File '2020_09_o.zip' removed successfully.
# File '2020_10_o.zip' removed successfully.
# File '2020_11_o.zip' removed successfully.
# File '2020_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_01_o.zip
# File '2021_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_02_o.zip
# File '2021_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_03_o.zip
# File '2021_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_04_o.zip
# File '2021_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_05_o.zip
# File '2021_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_06_o.zip
# File '2021_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_07_o.zip
# File '2021_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_08_o.zip
# File '2021_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_09_o.zip
# File '2021_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_10_o.zip
# File '2021_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_11_o.zip
# File '2021_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2021/2021_12_o.zip
# File '2021_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2021_01_o.zip' removed successfully.
# File '2021_02_o.zip' removed successfully.
# File '2021_03_o.zip' removed successfully.
# File '2021_04_o.zip' removed successfully.
# File '2021_05_o.zip' removed successfully.
# File '2021_06_o.zip' removed successfully.
# File '2021_07_o.zip' removed successfully.
# File '2021_08_o.zip' removed successfully.
# File '2021_09_o.zip' removed successfully.
# File '2021_10_o.zip' removed successfully.
# File '2021_11_o.zip' removed successfully.
# File '2021_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_01_o.zip
# File '2022_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_02_o.zip
# File '2022_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_03_o.zip
# File '2022_03_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_04_o.zip
# File '2022_04_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_05_o.zip
# File '2022_05_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_06_o.zip
# File '2022_06_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_07_o.zip
# File '2022_07_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_08_o.zip
# File '2022_08_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_09_o.zip
# File '2022_09_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_10_o.zip
# File '2022_10_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_11_o.zip
# File '2022_11_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2022/2022_12_o.zip
# File '2022_12_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# File '2022_01_o.zip' removed successfully.
# File '2022_02_o.zip' removed successfully.
# File '2022_03_o.zip' removed successfully.
# File '2022_04_o.zip' removed successfully.
# File '2022_05_o.zip' removed successfully.
# File '2022_06_o.zip' removed successfully.
# File '2022_07_o.zip' removed successfully.
# File '2022_08_o.zip' removed successfully.
# File '2022_09_o.zip' removed successfully.
# File '2022_10_o.zip' removed successfully.
# File '2022_11_o.zip' removed successfully.
# File '2022_12_o.zip' removed successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2023/2023_01_o.zip
# File '2023_01_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2023/2023_02_o.zip
# File '2023_02_o.zip' downloaded successfully.
# ZIP file contents extracted successfully.
# https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/2023/2023_03_o.zip
# File '2023_03_o.zip' downloaded successfully.
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In [4], line 21
#      19 for zip_url in zip_files_by_year:
#      20     print(zip_url)
# ---> 21     download(zip_url,year_path)
#      22 remove_zip_files(year_path)
#
# Cell In [3], line 25, in download(url, save_dir)
#      23     # Extract the contents of the ZIP file
#      24     with zipfile.ZipFile(filepath, 'r') as zip_ref:
# ---> 25         zip_ref.extractall(save_dir)
#      26     print("ZIP file contents extracted successfully.")
#      27 else:
#
# File c:\Python310\lib\zipfile.py:1634, in ZipFile.extractall(self, path, members, pwd)
#    1631     path = os.fspath(path)
#    1633 for zipinfo in members:
# -> 1634     self._extract_member(zipinfo, path, pwd)
#
# File c:\Python310\lib\zipfile.py:1689, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1685     return targetpath
#    1687 with self.open(member, pwd=pwd) as source, \
#    1688      open(targetpath, "wb") as target:
# -> 1689     shutil.copyfileobj(source, target)
#    1691 return targetpath
#
# File c:\Python310\lib\shutil.py:195, in copyfileobj(fsrc, fdst, length)
#     193 fdst_write = fdst.write
#     194 while True:
# --> 195     buf = fsrc_read(length)
#     196     if not buf:
#     197         break
#
# File c:\Python310\lib\zipfile.py:923, in ZipExtFile.read(self, n)
#     921 self._offset = 0
#     922 while n > 0 and not self._eof:
# --> 923     data = self._read1(n)
#     924     if n < len(data):
#     925         self._readbuffer = data
#
# File c:\Python310\lib\zipfile.py:1013, in ZipExtFile._read1(self, n)
#    1011 if self._left <= 0:
#    1012     self._eof = True
# -> 1013 self._update_crc(data)
#    1014 return data
#
# File c:\Python310\lib\zipfile.py:941, in ZipExtFile._update_crc(self, newdata)
#     939 # Check the CRC if we're at the end of the file
#     940 if self._eof and self._running_crc != self._expected_crc:
# --> 941     raise BadZipFile("Bad CRC-32 for file %r" % self.name)
#
# BadZipFile: Bad CRC-32 for file 'o_d_03_2023.csv'

# %%
os.listdir(output_data_path)
# Out:
# ['1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022']
